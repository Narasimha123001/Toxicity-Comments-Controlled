# %%
from googleapiclient.discovery import build
from textblob import TextBlob
import pandas as pd
import re
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Replace with your YouTube Data API key
API_KEY = 'API KEY'

# Function to extract video ID from URL
def extract_video_id(url):
    match = re.search(r'(?:v=|\/|embed\/|youtu\.be\/|watch\?v=|watch\?v%3D|watch\?v%253D)([a-zA-Z0-9_-]{11})', url)
    if match:
        return match.group(1)
    else:
        raise ValueError("Invalid YouTube URL or video ID could not be extracted")

# Function to fetch comments from a YouTube video using the YouTube API
def get_youtube_comments(video_url, api_key):
    video_id = extract_video_id(video_url)
    youtube = build('youtube', 'v3', developerKey=api_key)

    comments = []
    next_page_token = None
    page_count = 0

    while True:
        print(f"Fetching page {page_count + 1}...")  

        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100,
            textFormat="plainText",
            pageToken=next_page_token
        )
        response = request.execute()

        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comments.append(comment)

        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

        page_count += 1

    print(f"Total pages fetched: {page_count}") 
    print(f"Total comments fetched: {len(comments)}")  # Print total number of comments
    return comments

# Function to classify sentiment using TextBlob
def classify_sentiment(comment):
    analysis = TextBlob(comment)
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity == 0:
        return 'Neutral'
    else:
        return 'Negative'

# Sample labeled comments for evaluation (for demo purposes)
labeled_comments = [
    {"comment": "I love this video!", "label": "Positive"},
    {"comment": "This is boring.", "label": "Negative"},
    {"comment": "It's okay.", "label": "Neutral"},
    {"comment": "Amazing content, keep it up!", "label": "Positive"},
    {"comment": "Terrible editing.", "label": "Negative"}
]

# Function to calculate and print evaluation metrics
def evaluate_model(predictions, true_labels):
    accuracy = accuracy_score(true_labels, predictions)
    precision = precision_score(true_labels, predictions, average='weighted')
    recall = recall_score(true_labels, predictions, average='weighted')
    f1 = f1_score(true_labels, predictions, average='weighted')

    print("Evaluation Metrics:")
    print(f"Accuracy: {accuracy}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f"F1-Score: {f1}")

# Main function to scrape, classify comments, and print summary
def classify_comments_from_video():
    video_url = input("Enter the YouTube video URL: ")

    try:
        # Fetch all comments
        comments = get_youtube_comments(video_url, API_KEY)

        # Initialize counters and lists
        sentiment_counts = {'Positive': 0, 'Neutral': 0, 'Negative': 0}
        predictions = []
        positive_comments = []
        negative_comments = []

        # Classify each comment and count sentiments
        for comment in comments:
            sentiment = classify_sentiment(comment)
            sentiment_counts[sentiment] += 1
            predictions.append(sentiment)

            if sentiment == 'Positive':
                positive_comments.append(comment)
            elif sentiment == 'Negative':
                negative_comments.append(comment)

            print(f"Comment: {comment}")
            print(f"Sentiment: {sentiment}")
            print("-" * 80)  # Separator for readability

        # Print sentiment summary
        print("Sentiment Summary:")
        print(f"Total Comments: {len(comments)}")
        print(f"Positive: {sentiment_counts['Positive']}")
        print(f"Neutral: {sentiment_counts['Neutral']}")
        print(f"Negative: {sentiment_counts['Negative']}")

        # Save positive comments to CSV
        if positive_comments:
            pd.DataFrame(positive_comments, columns=["Positive Comments"]).to_csv('positive_comments.csv', index=False)
            print("Positive comments saved to positive_comments.csv")

        # Save negative comments to CSV
        if negative_comments:
            pd.DataFrame(negative_comments, columns=["Negative Comments"]).to_csv('negative_comments.csv', index=False)
            print("Negative comments saved to negative_comments.csv")

        # Evaluation (using the labeled comments)
        true_labels = [item['label'] for item in labeled_comments]
        test_predictions = [classify_sentiment(item['comment']) for item in labeled_comments]
        evaluate_model(test_predictions, true_labels)

    except Exception as e:
        print(f"An error occurred: {e}")

# Run the function
classify_comments_from_video()
# Out:
# Streaming output truncated to the last 5000 lines.
# --------------------------------------------------------------------------------
# Comment: Trump and Shannon sharpe doing all types of fake things to get people attention
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: The left are terrified of this man, they called him racist, but then we seen pictures of him with all the great black leaders, he even won an award for helping black people that was awarded to him by Rosa Parks, even Mike Tyson couldn’t believe they called trump racist, then they called him a rapist but there was absolutely no evidence so it didn’t go anywhere , then a pedophile simply because he loves his daughter so much. they rigged his Election, they then impeach him but that didn’t stop him, they then called him a Russian asset and said he spied on Hillary‘s campaign, so the FBI looked into it and all they found was that Obama spied on Trump‘s campaign, they then said he paid people off for sex, they then raided his home, they then arrested him, they then took him to court twice, all that failed so they shot him in the face, that still failed as he raised his fist, and now they have shot at him again, the left want him deleted so bad, they won’t stop,  and that’s a sure sign he’s doing good,, the only sad thing is he will NEVER become president again, they will rig it again even more so this time, they will try and delete him, if that doesn’t work next is the rigging
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: A President that can't be bought is the  fear of the kommies
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Just because a shot is fired in a state that Trump is in, doesn't mean it's a assassin's attempt.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Drama continues 😂😂😂
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: I swear something fishy 🐠 about this . I can’t trust media anymore most probably a red flag 🚩 to win over the public
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: I'm curious, since there's another assasination attempt, can all the Hollywood celebrities that said "don't miss next time" be charged for Incitement?
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: The left are clearly the problem here!
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: 100% setup - deflecting from his LOSING DEBATE
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: I just dont believe this vrap.. It is just another Tdump involved, staged event in America for them to think Trump is the all and be all king, who needs votes ..to stay out of jail.
# Why would anyone want to risk their own life in Jail for such a narcissistic money grubbing dementia patient, who can't keep it in his pants, perverted self absorbed pathetic human cretin who wants to be president again to save his own tiny pecker brain.
# I don't believe it's real.. FAKE NEWS as he says all the time. :-(
# Next he will say it was a Taylor Swift Psycho fan and she told them to do it.. convenient that an AK-45 was left behind .. in the bushes
# Don't tell me Tdump wasn't involved to set this play up..
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: This guy is a huge problem for this country. The country will be at peace once he loses in November
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: It was someone trying to shoot their duck dinner on the course pond.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: He also said in the email to supporters “I will always love you for supporting me. Unity. Peace. Make America Great Again.”. BBC trying their best to appear impartial
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: I think they are making this up, 3 times and they still missing
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Hilary Clinton was seen running from the scene.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: I blame the media
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: There is a large insect at about 2 10 crawling up the commentators right shoulder.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: What the hell is up with people sickos.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Full 111% Safety and Security, Defense and Protection for President Trump now!
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Y'know, I dunno why, but I'm starting to think some people don't really like this Trump fellow.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: It's f.....g disgusting what the democrats have allowed to happen in the USA
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Funny how No Network is reporting on this?  Oh wait it’s because the Dems are running them!!!  Wake up America.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: The Democrats all behind it to win elections. I pray God builds a protection around President Trump.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Secret service is a joke
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: This time it’s fore,fore,fore. They nicked my ball
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Wow they really are doing anything to take him outta this world. Sounds like their scared he may win.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Oops, I did it again
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Multiple shots in the bush while between holes.
#
# Trump says he feels his swing is probably the best anyone has ever seen. Infact many have commented on it.
#
# Glad he is ok👍....this world without a Trump....impossible.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: I just find this all very strange given how long he’s been around… all of a sudden it’s open season? I wouldn’t rule out a perverse PR attempt to make him look like some kind of Kennedy.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Again?
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: So secret service shot at suspect and missed?  😅
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Meh
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Im not a conspiracy type of person, but this feels like a desperate attempt to keep him relevant after he got dunked on in the debate.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: I wonder which patsey they got to try and assassinate trump this time
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Nothing to see here. Move along. Something's not right with all this.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: I have to say, this is politically counterproductive. Why? Because half the US population believe the exact opposite of anything.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: When the first False Flag Operation didn't achieve the desired rise in support, a second is apparently necessary... 🙄
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Haha he's trying to get popular again lol
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Happens every day...what to say...
# Did he duck the bullet?...
# Are his ducks ok?...nobody talking about the ducks any more...
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Civil war is coming
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: These assassination attempts are entirely the fault of the left wing politicians and media, saying wildly untrue things like he'll be the next Hitler (he was already president - he didn't do anything remotely Hitler like in office). This wild rhetoric causes unhinged leftists to literally commit murder. Everyone needs to wake up, smarten up and grow up.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Trump is bringing unwanted, safety issues and unwanted attention to the residents of Palm Beach
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: this man is more hated than i thought
# i mean i know hes hated worldwide but even though hes a very crazy person he doesnt really deserve to die
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: It seems like Malania don't care who finds out now she's not willing to go thru 4 more years of this BS, so is trying to end it b4 it starts 😂
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: CNN, and a few others, are responsible for stoking up this violent hatred. They are a disgrace and should be shut down.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Trumps ears are gonna end up more pierced than a punk rocker 😂
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: This is crazy...evil trying to servive...they will keep trying!
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Will Trump ban assault weapons if he becomes president NOPE
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: This is wrong
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: This is becoming a trend!
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Excellent coverage. Better than the garbage from US media
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Say fully or semi automatic or americans wont take you serious with your assault buzz word
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: It was probably the bank trying to get their loans back from him before he declares bankruptcy again again again again
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Staged 😂😂😂😂😂😂
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Another "assassination attempt"? Isn't it strange how they only ever happen when he experiences a dip in the polls, and they never cause him harm (unless he has a magical, regenerating ear)? 🤔
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: These ppl key missing ffs 🤦🏻‍♂️
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: It is so odd an Indian astrologer on interview with an Indian channel had said "there will be another attempt of DT life"
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Doesn’t get much luck does he Jesus
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Oh well, just a fact of life in the US.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: First they try to silence you, then they try to throw you in prison and finally if that doesn't work they kill you.
#
# This is actually getting scary. Why are the global elites so afraid of a Trump presidency.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: The wild wild west!!!
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Trump staging these assassination attempts to win sympathy
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: I actually feel sorry for him. You would think he’s Putin! He needs to forget about this election. He should just go live out the rest of his life (realistically 10 years MAX) in peace.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Too suspicious imo.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: I want to see the result of proper investigation …
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: 0-2 Trump
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Democrat leaders with their hateful rhetoric are 100% responsible for this and it will likely not be the last time. Obama's puppets need to be held accountable by Law Enforcement.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: “I’m still standing better than I ever did.”
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Land of the free aye? Just as long as you dont disagree with specific political views aye?
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: 2:02 is crazy 👀😭🤣
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: The suspect is ‘Some Puerto Rican guy’ of average Puerto Rican height…
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Inside job for sure😂
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Another fund me again in progress…
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Why does the BBC use quotation marks in title😂
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: mass media to blame
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: democrats really tryna kill the guy
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: The bbc is a cesspit.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Another publicity attempt, he's so very desperate now.  We're not falling for it
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Left Can't -Meme-
# Left Can't Aim.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Another upset unhinged trump supporter realising he's been duped by this charlatan
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: These wants to kill TRUMP :
#
# 1) Democrats of US + FBI
# 2) NATO + European Union
# 2.1 ) BBC is part of 2
# 3) Iran
#
# Only because elite can have all the money & wealth. B*****ds.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: They sure don't want him to be elected again.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Picture this - some guy is firing at trees, tRump's such a coward he thinks it's about him
# 😂😂 Dude is an absolute pussy.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Is the main stream media reporting truth for a change?  Hmmmm
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: You tried to kill him again, AND FAILED AGAIN? Do you have stormtrooper aim?
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Meanwhile all Kamala is interested in is debating this man. Doesn't condemn the attempt on his life. He made a comment about it at the last debate and she didn't say anything. She's classless and clueless all at the same time
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: 50 cent planning a show now
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Im engIish and dont know much about firearms but that seems like a long way for an AK with a scope... Maybe its doable if you're really well practised and theres no wind or something?! But it seems like a bolt-action is what youd be after, right? Isnt 7.62 a really heavy round thats not moving (comparatively) very fast?
#
# Good old donald. Like neo in the matrix. But orange.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: He got whooped in the debate and all of a sudden a "assassination" attempt is made on him. Yea real convenient it seems that he's so far down in the poles that he needs something to distract people from his awful performances.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: This is the media's fault
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Is that a cockroach or a moth or something that's crawling all over the presenter in the last few seconds of the video? lol
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Never has a politician been targeted to this extent. They are so afraid. They know Trump is onto something.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: but it's the right that is somehow extreme isn't it?
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Pls stop campaigning!!! You will win if you stay alive.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: this happened once its happened again something is soo rigged
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: The CIA just don't make them like they used to
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: 🧢🧢🧢
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Only sissys try copycat crimes.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: not again for fucks sake
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Inside job again
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Fraudster trump may have stage a hoax like that to win votes of pity or victim
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: *media constantly demonizes and depicts Trump as the end of democracy*
#
# *Deranged nut tries to take action*
#
# "Seems fishy to me guys"
#
# Just like last time, right?
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Trump's such a pussy ngl, just wow. 😂😂😂😂
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: A load of bollocks,
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: The most corrupt and messed up country in the world and they don't even realise it.
# They still believe they are a civilised country.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Absolute garbage, the man is so desperate for votes. BBC trusting the FBI for accurate information?????
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: This whole situation just feels so surreal, like something out of a movie, right? 🎬 I wonder how many layers there are to this story that we don’t even know about yet. Makes you think about how crazy things can get in the world of politics. 😬
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: 😂😂😂😂😂😂 democrazy
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Trunk got opps everywhere
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: If something happens to trump the government did it !!!
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: His hair saved him.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Just another publicity stunt from that stinking orange lying POS TRAITOR! Those 'gun shots' weren't anywhere near that orange MOFO! He's already got a grift going from it!!! I call BULLSH*T ....
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: the media, places like the BBC are responsible for the online radicalisation of many , through their outright lies . Even in the last debate Harris outright lying about trump and the moderators don't correct here.
#
# But she gets to lie , lie ,lie
# the Media has created and enabled violent extremists, and the BBC shares that blame
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: The 🌎 is a stage
# Enjoy the movie 🎬
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Load of shit same as lasttime sympathy seeking
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: All Bullshit
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: again ,lol they really don't want him to win do they
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: 400 million+ guns in the US.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: It’s all arranged by himself - do people not see thru this, the man’s a fekim phsico
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: When they confirm that this was staged, I hope that there is swift justice, because for a “presidential candidate” whose life was in danger just a few short weeks ago, to be playing golf, wide open for another”assassination attempt” it seems a bit incredulous! This is a distraction for the media from his horrible debate performance. Don’t fall for it. 💙🩵💙🩵
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: How can he be trusted to secure the border if he can't even secure his own golf course?
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: One of two things might be going one here!!! The one hiring these bad aiming dudes know nothing or they are hiring them knowingly to get some attention. I go for the 2nd one🤔!!!!!
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Apparently all of his enemies are stormtroopers
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: only took me an hour to find a true headline with actual facts instead of "shots fired" which is misleading and downplaying what happened to some random shots off in the distance...  IT WAS THE SECRET SERVICE THAT WAS FORCED TO SHOOT AT AN ASSASIN WITH A AR!!!!!   stop lying and misleading ggle and yutb!  every main stream media wants to mislead you bcause the deep state dems write their checks.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Why do they keep missing
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Here we go again with the same boll*cks
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: 2 attempts and bro still is standing strong
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Why did he Miss
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: The CIA
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Did anyone see that bug on the reports right shoulder....lol
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: What has trump done to deserve this? I'm sure im gonna get a list from someone but I wonder if the world thinks Putin is more...worth the effort?
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: I wander who will be blamed for it. Haitian criminal who's going back to Venezuela (Trump can't make up his mind about it) or Haitians who eat dogs and cats.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: First world country KEK
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Why are people talking more about the butterfly than the fact that trump almost got shot again?
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Anybody listening to this it’s LIEs from trumps campaign team FACT it was not in the golf course at all
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: FBI did it again.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: The first one had better TV ratings
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Democratic party is evil from satan
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: b safe the don father 🙏
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: I know this dude is thinking " I can't go anywhere without getting shot at" 😞
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Oh dear, may the Lord protect him🙏🏽
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: These folks are terrible snipers😂😂😂
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: many on the left are extremists, with no sense of reason, compassion, dark hearts
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: God bless us all. This is a terrible moment in our country. Mental illness is rampant - people are so seriously deranged. They need help.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: The clue is in the word apparent assassination... wouldn't be surprised to learn that this is Trumps people trying to gain the narrative back from Kamala Harris... assassination did so well for him last time.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: “FORE!!”
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Donnie is pulling shit out of his ass like usual 👎
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Trump before: “it didn’t work the way I wanted with the first guy. What a shaaame.
# We need more votes, make it real this time, but don’t kill me 0okay? …What a great guy”. Trump post assination: “ That assassin is a bad guy… what a bad Guy.. .How could he miss?”
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: "Donald, just take the hit. .I mean hint!"
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Very convenient distraction once again. Especially after reading about his poor performance during the presidential debate!
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: “Gunshots fired in his vicinity.” It was an another ASSASSINATION attempt you lying POS.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Oh brother... Now we'll never hear the end of it 🙄
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: I know he is polarising, but damn it's fake or there is a lot of hate on the other side.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Please don’t make this miserable excuse for a man a martyr.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Yahhh it was another assasination attempt lol why even try making statements questioning that.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: If it happens once it's a huge shock. It's awful that that man was killed during that rally. If it happens twice? No, this is just even more suspicious than the first time. Private golf course, SS security ramped up substantially after the first attempt, and this time it's someone hiding in the woods at an even greater distance? I'm definitely going conspiracy theorist on this when I say that this has to be some kind of ploy to garner failing support and increase donations for his campaign from his loyal cultists. There's no way this shit happens twice man.
#
# Edit: Lol he actually used this as a way to ask for more donations. This shit is just stupid predictable.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Trump's golf game wasn't on his official "schedule" only his personal Secret Service knew. Not good
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Trump derangement syndrome.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Socialists are dangerous and wicked.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Something is fishy. How did the gunman know his location? It's either someone is really trying hard to set him up or it's just to boost ratings, given the current situation.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: These assassination attempts are just a fact of life. Trump needs to get over it and move on. Also, thoughts and prayers.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Trump 2024! It will happen. America is Trump and Trump is America.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Hmm! 2nd 'attempt' at assassinstion  followingvperiods of unpopularity.Coincidence?  I think not!
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: The kitten eating gangs are targeting Trump.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: lol wtf
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: that moth is telling him secretly what to say
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: The swamp do not want him back... the warmongers don't want him back... Starmer doesn't want him back.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Why does he keep saying apparently? Hmm 😒
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: They will blame some bloke who has mental health issues…
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Of course, getting rid of Trump will give his political party a chance at winning, as it is now, the laughing clown woman will most likely win, so getting rid of Orange Man will maybe stop that. You really have to laugh at American politics, it really is a comedy of clowns and jesters. And, how shit are American assassins these days ?
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: What now? his right ear ?
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: I was a Democrat until this and because of this im voting for trump.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Chargers are 2-0!! Let's go Boltz⚡
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: They are really after him.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: This is the lefts fault.... They think it is totally acceptable to "demonise" an opponent and don't give a damn about the consequences.  My God American people... WAKE UP.  a conspiracy theory does not involve missing by millimetres a headshot so close in fact it went through Trumps ear..  The left basically are hoping they can wind someone up enough to take him out.  Double wammy for them of course as amid all the fake sorrow they could blame gun laws for his death.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: I predict this might become a recurrent occurrence until the election. I mean, he can't win debates, needs to build up a messianic reputation or some shite... Oof, Muricah....
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: He’s safe? Fuuuuuccccckkkkk!!!!!!!
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: "an AK-47 assult rifle has apparently been recovered" - is this journalism or speculation? Why not stick to the facts and what can be verified.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: And still millions won't wake up. There is some shifty business going on here. Think someone in Kamalas camp is getting nervous.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: The game was declared a draw.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: BBC LIES are complicit in the attacks on DJT.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: did anyone see that big ass bug crawling on dude
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: BBC/MI6 anybody you know
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: "It's a fact of life " Vances statement after 4 killed in school shooting
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: For some reason I'm reminded of a great line in the original "Dawn of the Dead" film where Ken Foree's character picks up an expensive rifle in the mall's gun-shop, peers down the scope, and says "The only guy who could miss with this is the guy who could afford it."
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: The Democrats are most definitely behind this
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Anyone else see the shoulder bug?
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: This is sad and insane.
# God bless America 🇺🇸 and help you make the right choice.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: If only the good die young, and Donald is pushing 80 and has survived 2 president-level assassination attempts, does that make him Satan?
#
# Bill Hicks said Reagan was Satan and he survived an attempt. What does that make Donald?
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: How many shootings of us presidents or ex presidents ….need to get rid of guns .lbut UzsAxwhen are you going to realise your lack 9f gun laws cause gun violence
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Media: Trump and a gunman
# Everyone else: Did you see that bug?
#
# 😂
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Reports are saying that the shots heard were from the Secret Service who discovered the suspect. The suspect did not take any shots at Trump.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Leftis will say that its trumps fault he entices people to kill him. He should not run his mouth offending idiots.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Somebody really doesn’t want this guy in power…
#
# What are they hiding???
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: More Bull Shit
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: We wont see this covered at all lol
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Attention seeking
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: This was not an attempt on his life, he was reported to not be the target, two men were shooting at each other.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: It’s rigged
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Making news by trump
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: The Anti-Trump comments
# here are all from BBC shills
# The pro-Trump comments
# are all from ordinary people
# Trump is Winning ✊😻✊
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Dumb Americans
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Democrats are completely unhinged.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Ngl, I was a bit confused to begin with. When they said they were going to the correspondant in Washington, I thought Trump owned a golf course in Tyne and Wear. I then also thought "why would someone try to assassinate him in the UK?" and "how on earth did someone get their hands on an AK-47 in the UK, but when they mentioned that Donald Trump was in a place that was clearly not the UK, I pieced together than it was all in the US. Still am confused as to why the correspondant is on the west coast of the US in Washington rather than on the East near Florida. Maybe there are going to debates in Seattle?
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Poll numbers wers tanking.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: How can you report this. This has already been debunked as rot, it is total lies. It had nothing, NOTHING whatever to do with Trump with the incident way outside the vicinity of where he was. His propergander lunatic Stephen Cheung [utout this rubbish to deflect and give sensational headlines to steer people away from the fact that he is waning in USA. Trump should disappear full stop! Lunatic!
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Hilarious how the same sheeple who cry "conspiracy theory!" every time anyone questions the political establishment are acting like deranged schizos about these assassination attempts.
#
# Its like these NPC's will only believe whatever the globalist establishment wants them to believe.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: My bad guys i cant perform when its chilly
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: “It’s a fact of life.”  -JD Vance
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: I have a feeling if Donny loses he will flee the country
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Why does the far left always use violence to silence democracy? The so called far right haven't tried to assassinate Joe Biden, though that's probably because no one would even notice the difference!
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Hey man, you are bugged there.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: But were any pets eaten by the gunman
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: When is this going to stop? How many times must the far left try to murder Trump before we have a serious discussion about the threat that far left terror poses to our democracy?
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Will the deep state remain silent after Trump wins
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Another assasination attempt, United States is like a third world African country.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: CIA trying to do their job
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Does the shooter get a mulligan?
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: The left are really trying to kill this guy... its so clear that he messes with "their plans" they're agenda. Wild
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: They missed again ?
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: This is looking awfully suspicious now…
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: That bug on his shoulder..!!
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: https://youtu.be/HXL3XOSLV3A
# Mark 13:7
# And when ye shall hear of wars and rumours of wars, be ye not troubled: for such things must needs be; but the end shall not be yet.
#   MUST SEE B4 ITS TAKEN DOWN.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Ryan Wesley Routh.
#
# Migrant crime is on the rise though. Give me a break.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Ah the BBC.....from greatest news in history to left wing propaganda wing.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Bug appears @2:02 mins in.  Just saw the bug, on his shoulder, crawling down the right side of his suit jacket. 🪲🦋
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: They democrats are scared of freedom
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: A put up job because he's getting beaten by Kamala!
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: La troisième sera la bonne. Just keep going brothers 👍
# Sentiment: Neutral
# ...
# Comment: This is deliberate act. Shame on Biden and Harris.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Another staged  voting  scam .
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: USA is wild 💀
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: I SMELL BS
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Everyone who hates him is gritting their teeth now.
# Firstly cause he's safe.
# Secondly because they have to report on something that gives Trump favour among the public.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: They are eating the dogs... They are eating the cats... The people that came in... They are eating the pets of the people that lived there🤭
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Lizard people hate Trump. As do sheep.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: We all know the elite want trump dead
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Already proved to be a lie
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Another's  lie
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: They couldn't even find out what happened last time !!
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Uh sh*t... Here we go again.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: One suspect is Mr. Donald T...
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: But no far leftists arnt a problem
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Incredible that people keep blaiming Kamala for this. 🤦‍♂️
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Thie man is just about drama! This gunshots had nothing to do with him!
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: First time i believed it wasn't fake, second time 🤔
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Just another GOP attempt to replace Trump with a better candidate who has a higher chance of defeating Harris. Where are my conspiracy theorists?
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: He has won the election now  🇺🇸🇺🇸
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: There was no attempt on Trump it's all fake news
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: so what happened to democracy and free and fair elections looks like the candidates are targets ...this is similar to Nicaragua and mexico somebody is funding these shooters
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: MF AGAIN?
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: It was the FBI that arranged it, but their diversity hires keep messing up 🤣
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Great. They are investigating themselves?
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: This 2nd CIA attempted assassination of President Donald J Trump is utter woke nonsense
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: BS set up 😂😂😂😂
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: 😑
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Don't Forget PROJECT 2025 is Treason is Dehumanizing is Trump
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: The question to ask : how did this guy know Trump would be on the course. Trump only decided to play golf a few hours earlier?
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Trump its fake news nasty questions.  I hate Taylor swift.  They eating ur cats they eating ur dog 😂😂😂😂😂😂😂😂
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Another pathetic amateur!
# "Mortem Tyrannis!!!"
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: He’ll blame it on communists or radical leftists.
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Spew hate and racism, you draw this attention to yourself
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Don't let the fbi investigate anything
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: bug
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Someone tried to assassinate Donald Trump for the second time?
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Trump said about the dead children killed in school "we just have to get over it"
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: So, let me guess...
# Trump will now claim that not only was he shot, but that he caught the bullet with his bare hands and threw it back at the suspect.
# 😏
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Another BS all staged to make him look good. How did election degenerate to this?
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Leftist?
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: I wonder where the lying Fascist Convicted Felon, Traitor Trump, the Russian spy, will wear the fake bandage this time? The third time is the charm.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: And on todays episode of TRUMP LIFE.......
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: FBI has confirmed that this was the second attempt on President Trumps life.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Publicity stunt and I bet the newest sneakers are ready to roll out.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: He will once again make himself an orange victim of hatred   🤔 The shooter was either an immigrant or a cat lover. 😑Shooter was illegal immigrant or swiftie or even worst illegal immigrant and swiftie at the same time🤥
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Who wants to bet the FBI had various versions of their statement written before the shooting took place?
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Next week GOLD $2700 🚀
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Someone said remember JD Vance said "shootings are a part of life"
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: MK Ultra Soldiers getting activated more and more
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: I heard that Swifty's hate Trump.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: They caught the guy using license plate readers. WTF? We're paying out tax dollars so the government can track us?
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Who saw the butterfly on the man at 2:06
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: https://youtube.com/shorts/Sc5wmTRy0Z4
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Assalamualaikum alhamdulillah insyaallah semoga keadilan selalu di tegakkan 😊😅😮😢😢😂
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: IT WAS A FAKE! https://youtu.be/RuIQRfp0sU0?si=1nr-nfUTM05q4Xsx
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: And why was this guy able to fire the gun?  Where was SS?  The secret service should have secured the entire area at all times!
# Very shady!
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: This is disgusting… they can’t beat him so they just keep on trying to hurt him!!!!
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Why would they waste taxpayers money on this investigation... IT's FLORIDA! Everyone & their dog carries/uses a gun.  This is a giant nothing-burger. (the campaign is making it out to be more than it is)
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Remember, Dems want to take your guns away while your presidential nominee survives his second assassination attempt. The Dems are angry.
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Trump really about to die before GTA 6
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Democrats and the media are responsible for this by spewing hatred and injecting their political bias into non-stop negative reporting on President Trump
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Our media in America is bought and paid for to lie. Now they’re pretending cats and dogs, geese and ducks are not being eaten by illegal humans. This is amazing because the Animals in Shelters are being killed daily!!
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Anyone else see the bug crawling on his right shoulder?? Haha
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Democratic Party Members Karen Kamala Harris CIA FBI Democratic Party Mafia Family Members
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Even more reason this man needs to be president.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Trump always promotes violence - and even threatens his political opponents if he gets elected. He supports the use of AK47s and other automatic and assault weapons. What a tangled web he weaves?
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Time to retire. Go F off to the  golf course with Biden and argue about who banged Hillary first.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: BS
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Hahaha Poland tells blinken go home get lost.....no one wants to die for your wars
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Here we go again
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Probably was his wife
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Bro can’t catch a break for once
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: These evil globalists, the New World Order is trying to kill him. This is very obvious! May God protect Mr. Trump.🙏🏻
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: Bet they got the other ear
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Comment: In a moment, in the twinkling of an eye, at the last trump: for the trumpet shall sound, and the dead shall be raised incorruptible, and we shall be changed. For this corruptible must put on incorruption, and this mortal must put on immortality. 1 Corinthians 15:52-53
#
# Let no man deceive you by any means: for that day shall not come, except there come a falling away first, and that man of sin be revealed, the son of perdition; Who opposeth and exalteth himself above all that is called God, or that is worshipped; so that he as God sitteth in the temple of God, shewing himself that he is God. 2 Thessalonians 2:3-4
#
# And I saw one of his heads as it were wounded to death; and his deadly wound was healed: and all the world wondered after the beast. Revelation 13:3
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: That's the election decided!
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Lol... The comedy, the staging ,the election  time in usa then.The First was staged and totally ripped apart.
# You just have to point and laugh at them.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: Trump gonna be milking this one next...
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Establishment really doesn't like him.
# Sentiment: Positive
# --------------------------------------------------------------------------------
# Comment: What the hell is happening in this once upon a time promised land???
# Sentiment: Neutral
# --------------------------------------------------------------------------------
# Comment: Predictable
# Sentiment: Negative
# --------------------------------------------------------------------------------
# Sentiment Summary:
# Total Comments: 5380
# Positive: 1570
# Neutral: 2254
# Negative: 1556
# Positive comments saved to positive_comments.csv
# Negative comments saved to negative_comments.csv
# Evaluation Metrics:
# Accuracy: 0.8
# Precision: 0.6666666666666666
# Recall: 0.8
# F1-Score: 0.72
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
